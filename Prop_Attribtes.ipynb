# %% [markdown]
# <a href="https://colab.research.google.com/github/SaimKhan9/Numpy/blob/main/Prop_Attribtes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5])

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1.shape
# Out:
# (5,)

# %%
arr2=np.array(([1,2,3],[5,6,7]))

# %%
arr2.shape
# Out:
# (2, 3)

# %%
arr3=np.array([[[1,2],[3,4]],[[1,0],[9,0]]])

# %%
arr3
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[1, 0],
#         [9, 0]]])

# %%
arr3.shape
# Out:
# (2, 2, 2)

# %%
#to find number of dimentions
arr3.ndim
# Out:
# 3

# %%
arr1.ndim
# Out:
# 1

# %%
arr1.size
# Out:
# 5

# %%
#size of the array
arr2.size
# Out:
# 6

# %%
#memory of each value in array
arr2.itemsize
# Out:
# 8

# %%
arr4=np.array([1,2,3])

# %%
arr3.itemsize
# Out:
# 8

# %%
arr3
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[1, 0],
#         [9, 0]]])

# %%
arr3.itemsize
# Out:
# 8

# %%
arr3.dtype
# Out:
# dtype('int64')

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
arr1.astype('float')
# Out:
# array([1., 2., 3., 4., 5.])
